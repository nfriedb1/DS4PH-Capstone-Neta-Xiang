# %%
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

# %%
img = Image.open('lungs.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512 at 0x7FD7A16CA2E0>
